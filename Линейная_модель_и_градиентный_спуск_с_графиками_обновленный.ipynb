# %%
# Loss curve for both models

# Re-plot Loss Curve
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))

# Loss for Student_Performance
plt.plot(range(1, len(logreg_student_loss.loss_history) + 1), logreg_student_loss.loss_history, color='blue', label='Student_Performance Loss')

# Loss for German dataset
plt.plot(range(1, len(logreg_german_loss.loss_history) + 1), logreg_german_loss.loss_history, color='green', label='German Loss')

# Plot details
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('Loss Curves During Gradient Descent')
plt.legend()
plt.show()

# Feature Coefficients: Visualize the magnitude of the coefficients (weights) learned by the model

# For Student_Performance model
coefficients_student = logreg_student_loss.weights
features_student = X_train_student.columns

# For German dataset model
coefficients_german = logreg_german_loss.weights
features_german = X_train_german.columns

# Plot feature coefficients for Student_Performance
plt.figure(figsize=(12, 6))
plt.barh(features_student, coefficients_student, color='blue')
plt.title('Feature Coefficients (Student_Performance)')
plt.xlabel('Coefficient Magnitude')
plt.ylabel('Features')
plt.show()

# Plot feature coefficients for German dataset
plt.figure(figsize=(12, 6))
plt.barh(features_german, coefficients_german, color='green')
plt.title('Feature Coefficients (German)')
plt.xlabel('Coefficient Magnitude')
plt.ylabel('Features')
plt.show()

# Model Performance Over Time: A plot of ROC-AUC or accuracy during gradient descent iterations

# For Student_Performance
roc_auc_history_student = []
for i in range(1, len(logreg_student_loss.loss_history) + 1):
    y_pred_iter_student = logreg_student_loss.sigmoid(np.dot(X_train_student_scaled, logreg_student_loss.weights) + logreg_student_loss.bias)
    roc_auc_iter_student = roc_auc_score(y_train_student_binary, y_pred_iter_student)
    roc_auc_history_student.append(roc_auc_iter_student)

# For German dataset
roc_auc_history_german = []
for i in range(1, len(logreg_german_loss.loss_history) + 1):
    y_pred_iter_german = logreg_german_loss.sigmoid(np.dot(X_train_german_scaled, logreg_german_loss.weights) + logreg_german_loss.bias)
    roc_auc_iter_german = roc_auc_score(y_train_german, y_pred_iter_german)
    roc_auc_history_german.append(roc_auc_iter_german)

# Plot ROC-AUC Over Time for Student_Performance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(roc_auc_history_student) + 1), roc_auc_history_student, color='blue', label='Student_Performance')
plt.xlabel('Iterations')
plt.ylabel('ROC-AUC')
plt.title('Model Performance (ROC-AUC) Over Time (Student_Performance)')
plt.legend()
plt.show()

# Plot ROC-AUC Over Time for German dataset
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(roc_auc_history_german) + 1), roc_auc_history_german, color='green', label='German')
plt.xlabel('Iterations')
plt.ylabel('ROC-AUC')
plt.title('Model Performance (ROC-AUC) Over Time (German)')
plt.legend()
plt.show()

# Predicted vs Actual for Student_Performance
plt.figure(figsize=(10, 6))
plt.scatter(y_test_student_binary, y_pred_student, alpha=0.6, color='blue')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.title('Predicted vs Actual (Student_Performance)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()

# Predicted vs Actual for German dataset
plt.figure(figsize=(10, 6))
plt.scatter(y_test_german, y_pred_german, alpha=0.6, color='green')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.title('Predicted vs Actual (German)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.show()
